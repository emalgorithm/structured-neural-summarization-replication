# %%
# %load_ext autoreload
# %autoreload 2

from data_extraction import get_dataset_from_dir#, get_augmented_graph
import pickle
import matplotlib.pyplot as plt
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%time
methods_source, methods_names, method_graphs = get_dataset_from_dir()
# Out:
# A total of 100 files have been found
# Extracting data from file 1
# Extracting data from file 2
# Extracting data from file 3
# Extracting data from file 4
# Extracting data from file 5
# Extracting data from file 6
# Extracting data from file 7
# Extracting data from file 8
# Extracting data from file 9
# Extracting data from file 10
# Extracting data from file 11
# Extracting data from file 12
# Extracting data from file 13
# Extracting data from file 14
# Extracting data from file 15
# Extracting data from file 16
# Extracting data from file 17
# Extracting data from file 18
# Extracting data from file 19
# Extracting data from file 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Projects/mphil_acs/R252/my_code/data_extraction.py in get_dataset_from_dir(dir)
#     113         methods_source += file_methods_source
#     114         methods_names += file_methods_names
# --> 115         method_graph = get_augmented_graph(file)
#     116         method_graphs += [method_graph for _ in range(len(file_methods_source))]
#     117
#
# ~/Projects/mphil_acs/R252/my_code/data_extraction.py in get_augmented_graph(file)
#     147
#     148             # ADD NEXT_TOKEN edge from node before identifier to first sub-identifier
# --> 149             previous_token_node_id = find_previous_token_node_id(node, g)
#     150             augmented_graph.add_edge(previous_token_node_id, sub_identifiers_ids[0],
#     151                                      edge_type="NEXT_TOKEN")
#
# ~/Projects/mphil_acs/R252/my_code/data_extraction.py in find_previous_token_node_id(node, g)
#     174 def find_previous_token_node_id(node, g):
#     175     for edge in g.edge:
# --> 176         if edge.destinationId == node.id and edge.type == FeatureEdge.NEXT_TOKEN:
#     177             return edge.sourceId
#     178
#
# KeyboardInterrupt:

# %% [markdown]
# ## Methods Analysis

# %%
data = pickle.load(open('data/methods_tokens_data.pkl', 'rb'))
methods_source = data['methods_source']
methods_names = data['methods_names']
# method_graphs = data['method_graphs']

# %%
print("The repo contains {} methods".format(len(methods_names)))
# Out:
# The repo contains 88479 methods

# %%
np.max(methods_length)
# Out:
# 7088

# %%
methods_length = [len(method) for method in methods_source]
plt.xlabel('#(sub)tokens in method')
plt.ylabel('Frequency')
a = plt.hist(methods_length, bins=100, range=(0, 1000), )
plt.savefig("plots/tokens_per_method.png")

# %%
methods_names_length = [len(method_name) for method_name in methods_names]
print("The average number of sub-identifiers in a method name is: {}".format(np.mean(methods_names_length)))
plt.xlabel('#sub-identifiers in method name')
plt.ylabel('Frequency')
a = plt.hist(methods_names_length, bins=range(1, 20))
plt.savefig("plots/tokens_per_method_name.png")
# Out:
# The average number of sub-identifiers in a method name is: 2.807434532487935

# %%
data = pickle.load(open('data/methods_data_small.pkl', 'rb'))
methods_source = data['methods_source']
methods_names = data['methods_names']
method_graphs = data['method_graphs']

# %%
len(methods_names)
# Out:
# 1010

# %%
g.edge
# Out:
# [sourceId: 0
# destinationId: 1
# type: AST_CHILD
# , sourceId: 1
# destinationId: 2
# type: AST_CHILD
# , sourceId: 2
# destinationId: 3
# type: AST_CHILD
# , sourceId: 3
# destinationId: 4
# type: AST_CHILD
# , sourceId: 2
# destinationId: 5
# type: AST_CHILD
# , sourceId: 5
# destinationId: 6
# type: AST_CHILD
# , sourceId: 6
# destinationId: 7
# type: AST_CHILD
# , sourceId: 7
# destinationId: 8
# type: AST_CHILD
# , sourceId: 6
# destinationId: 9
# type: AST_CHILD
# , sourceId: 9
# destinationId: 10
# type: AST_CHILD
# , sourceId: 6
# destinationId: 11
# type: AST_CHILD
# , sourceId: 11
# destinationId: 12
# type: AST_CHILD
# , sourceId: 12
# destinationId: 13
# type: AST_CHILD
# , sourceId: 13
# destinationId: 14
# type: AST_CHILD
# , sourceId: 14
# destinationId: 17
# type: AST_CHILD
# , sourceId: 17
# destinationId: 18
# type: AST_CHILD
# , sourceId: 14
# destinationId: 19
# type: AST_CHILD
# , sourceId: 19
# destinationId: 20
# type: AST_CHILD
# , sourceId: 21
# destinationId: 22
# type: NEXT_TOKEN
# , sourceId: 22
# destinationId: 23
# type: NEXT_TOKEN
# , sourceId: 23
# destinationId: 24
# type: NEXT_TOKEN
# , sourceId: 24
# destinationId: 25
# type: NEXT_TOKEN
# , sourceId: 25
# destinationId: 27
# type: NEXT_TOKEN
# , sourceId: 27
# destinationId: 28
# type: NEXT_TOKEN
# , sourceId: 28
# destinationId: 29
# type: NEXT_TOKEN
# , sourceId: 29
# destinationId: 30
# type: NEXT_TOKEN
# , sourceId: 30
# destinationId: 31
# type: NEXT_TOKEN
# , sourceId: 31
# destinationId: 32
# type: NEXT_TOKEN
# , sourceId: 32
# destinationId: 33
# type: NEXT_TOKEN
# , sourceId: 33
# destinationId: 34
# type: NEXT_TOKEN
# , sourceId: 34
# destinationId: 35
# type: NEXT_TOKEN
# , sourceId: 35
# destinationId: 36
# type: NEXT_TOKEN
# , sourceId: 36
# destinationId: 37
# type: NEXT_TOKEN
# , sourceId: 37
# destinationId: 38
# type: NEXT_TOKEN
# , sourceId: 14
# destinationId: 33
# type: ASSOCIATED_TOKEN
# , sourceId: 4
# destinationId: 21
# type: ASSOCIATED_TOKEN
# , sourceId: 0
# destinationId: 22
# type: ASSOCIATED_TOKEN
# , sourceId: 0
# destinationId: 23
# type: ASSOCIATED_TOKEN
# , sourceId: 0
# destinationId: 24
# type: ASSOCIATED_TOKEN
# , sourceId: 8
# destinationId: 25
# type: ASSOCIATED_TOKEN
# , sourceId: 10
# destinationId: 27
# type: ASSOCIATED_TOKEN
# , sourceId: 6
# destinationId: 28
# type: ASSOCIATED_TOKEN
# , sourceId: 6
# destinationId: 29
# type: ASSOCIATED_TOKEN
# , sourceId: 6
# destinationId: 30
# type: ASSOCIATED_TOKEN
# , sourceId: 12
# destinationId: 31
# type: ASSOCIATED_TOKEN
# , sourceId: 18
# destinationId: 32
# type: ASSOCIATED_TOKEN
# , sourceId: 14
# destinationId: 34
# type: ASSOCIATED_TOKEN
# , sourceId: 20
# destinationId: 35
# type: ASSOCIATED_TOKEN
# , sourceId: 14
# destinationId: 36
# type: ASSOCIATED_TOKEN
# , sourceId: 12
# destinationId: 37
# type: ASSOCIATED_TOKEN
# , sourceId: 0
# destinationId: 38
# type: ASSOCIATED_TOKEN
# , sourceId: 39
# destinationId: 2
# type: ASSOCIATED_SYMBOL
# , sourceId: 43
# destinationId: 6
# type: ASSOCIATED_SYMBOL
# , sourceId: 44
# destinationId: 33
# type: ASSOCIATED_SYMBOL
# , sourceId: 26
# destinationId: 6
# type: COMMENT
# ]

# %%
g.node
# Out:
# [id: 0
# type: AST_ELEMENT
# contents: "COMPILATION_UNIT"
# startPosition: 0
# endPosition: 100
# startLineNumber: 1
# endLineNumber: 8
# , id: 1
# type: FAKE_AST
# contents: "TYPE_DECLS"
# startPosition: 0
# endPosition: 100
# startLineNumber: 1
# endLineNumber: 8
# , id: 2
# type: AST_ELEMENT
# contents: "CLASS"
# startPosition: 0
# endPosition: 100
# startLineNumber: 1
# endLineNumber: 8
# , id: 3
# type: FAKE_AST
# contents: "MODIFIERS"
# startPosition: 0
# endPosition: 6
# startLineNumber: 1
# endLineNumber: 1
# , id: 4
# type: AST_ELEMENT
# contents: "MODIFIERS"
# startPosition: 0
# endPosition: 6
# startLineNumber: 1
# endLineNumber: 1
# , id: 5
# type: FAKE_AST
# contents: "MEMBERS"
# startPosition: 46
# endPosition: 97
# startLineNumber: 4
# endLineNumber: 6
# , id: 6
# type: AST_ELEMENT
# contents: "METHOD"
# startPosition: 46
# endPosition: 97
# startLineNumber: 4
# endLineNumber: 6
# , id: 7
# type: FAKE_AST
# contents: "MODIFIERS"
# startPosition: 46
# endPosition: 52
# startLineNumber: 4
# endLineNumber: 4
# , id: 8
# type: AST_ELEMENT
# contents: "MODIFIERS"
# startPosition: 46
# endPosition: 52
# startLineNumber: 4
# endLineNumber: 4
# , id: 9
# type: FAKE_AST
# contents: "RETURN_TYPE"
# startPosition: 53
# endPosition: 57
# startLineNumber: 4
# endLineNumber: 4
# , id: 10
# type: AST_ELEMENT
# contents: "PRIMITIVE_TYPE"
# startPosition: 53
# endPosition: 57
# startLineNumber: 4
# endLineNumber: 4
# , id: 11
# type: FAKE_AST
# contents: "BODY"
# startPosition: 71
# endPosition: 97
# startLineNumber: 4
# endLineNumber: 6
# , id: 12
# type: AST_ELEMENT
# contents: "BLOCK"
# startPosition: 71
# endPosition: 97
# startLineNumber: 4
# endLineNumber: 6
# , id: 13
# type: FAKE_AST
# contents: "STATEMENTS"
# startPosition: 81
# endPosition: 91
# startLineNumber: 5
# endLineNumber: 5
# , id: 14
# type: AST_ELEMENT
# contents: "VARIABLE"
# startPosition: 81
# endPosition: 91
# startLineNumber: 5
# endLineNumber: 5
# , id: 17
# type: FAKE_AST
# contents: "TYPE"
# startPosition: 81
# endPosition: 84
# startLineNumber: 5
# endLineNumber: 5
# , id: 18
# type: AST_ELEMENT
# contents: "PRIMITIVE_TYPE"
# startPosition: 81
# endPosition: 84
# startLineNumber: 5
# endLineNumber: 5
# , id: 19
# type: FAKE_AST
# contents: "INITIALIZER"
# startPosition: 89
# endPosition: 90
# startLineNumber: 5
# endLineNumber: 5
# , id: 20
# type: AST_ELEMENT
# contents: "INT_LITERAL"
# startPosition: 89
# endPosition: 90
# startLineNumber: 5
# endLineNumber: 5
# , id: 21
# type: TOKEN
# contents: "PUBLIC"
# startPosition: 0
# endPosition: 6
# startLineNumber: 1
# endLineNumber: 1
# , id: 22
# type: TOKEN
# contents: "CLASS"
# startPosition: 7
# endPosition: 12
# startLineNumber: 1
# endLineNumber: 1
# , id: 23
# type: IDENTIFIER_TOKEN
# contents: "Test"
# startPosition: 13
# endPosition: 17
# startLineNumber: 1
# endLineNumber: 1
# , id: 24
# type: TOKEN
# contents: "LBRACE"
# startPosition: 18
# endPosition: 19
# startLineNumber: 1
# endLineNumber: 1
# , id: 25
# type: TOKEN
# contents: "PUBLIC"
# startPosition: 46
# endPosition: 52
# startLineNumber: 4
# endLineNumber: 4
# , id: 26
# type: COMMENT_JAVADOC
# contents: "/** @return 4 */"
# startPosition: 25
# endPosition: 41
# startLineNumber: 3
# endLineNumber: 3
# , id: 27
# type: TOKEN
# contents: "void"
# startPosition: 53
# endPosition: 57
# startLineNumber: 4
# endLineNumber: 4
# , id: 28
# type: IDENTIFIER_TOKEN
# contents: "helloWorld"
# startPosition: 58
# endPosition: 68
# startLineNumber: 4
# endLineNumber: 4
# , id: 29
# type: TOKEN
# contents: "LPAREN"
# startPosition: 68
# endPosition: 69
# startLineNumber: 4
# endLineNumber: 4
# , id: 30
# type: TOKEN
# contents: "RPAREN"
# startPosition: 69
# endPosition: 70
# startLineNumber: 4
# endLineNumber: 4
# , id: 31
# type: TOKEN
# contents: "LBRACE"
# startPosition: 71
# endPosition: 72
# startLineNumber: 4
# endLineNumber: 4
# , id: 32
# type: TOKEN
# contents: "int"
# startPosition: 81
# endPosition: 84
# startLineNumber: 5
# endLineNumber: 5
# , id: 33
# type: IDENTIFIER_TOKEN
# contents: "a"
# startPosition: 85
# endPosition: 86
# startLineNumber: 5
# endLineNumber: 5
# , id: 34
# type: TOKEN
# contents: "EQ"
# startPosition: 87
# endPosition: 88
# startLineNumber: 5
# endLineNumber: 5
# , id: 35
# type: TOKEN
# contents: "5"
# startPosition: 89
# endPosition: 90
# startLineNumber: 5
# endLineNumber: 5
# , id: 36
# type: TOKEN
# contents: "SEMI"
# startPosition: 90
# endPosition: 91
# startLineNumber: 5
# endLineNumber: 5
# , id: 37
# type: TOKEN
# contents: "RBRACE"
# startPosition: 96
# endPosition: 97
# startLineNumber: 6
# endLineNumber: 6
# , id: 38
# type: TOKEN
# contents: "RBRACE"
# startPosition: 99
# endPosition: 100
# startLineNumber: 8
# endLineNumber: 8
# , id: 39
# type: SYMBOL_TYP
# contents: "Test"
# startPosition: -1
# endPosition: -1
# startLineNumber: 0
# endLineNumber: 0
# , id: 43
# type: SYMBOL_MTH
# contents: "helloWorld()"
# startPosition: -1
# endPosition: -1
# startLineNumber: 0
# endLineNumber: 0
# , id: 44
# type: SYMBOL_VAR
# contents: "a"
# startPosition: -1
# endPosition: -1
# startLineNumber: 0
# endLineNumber: 0
# ]

# %%
len(g.node)
# Out:
# 40

# %%
graph = get_augmented_graph(g)

# %%
graph.edges.data()
# Out:
# EdgeDataView([(0, 1, {'edge_type': 'AST_CHILD'}), (0, 22, {'edge_type': 'ASSOCIATED_TOKEN'}), (0, 23, {'edge_type': 'ASSOCIATED_TOKEN'}), (0, 24, {'edge_type': 'ASSOCIATED_TOKEN'}), (0, 38, {'edge_type': 'ASSOCIATED_TOKEN'}), (1, 2, {'edge_type': 'AST_CHILD'}), (2, 3, {'edge_type': 'AST_CHILD'}), (2, 5, {'edge_type': 'AST_CHILD'}), (2, 39, {'edge_type': 'ASSOCIATED_SYMBOL'}), (3, 4, {'edge_type': 'AST_CHILD'}), (4, 21, {'edge_type': 'ASSOCIATED_TOKEN'}), (5, 6, {'edge_type': 'AST_CHILD'}), (6, 7, {'edge_type': 'AST_CHILD'}), (6, 9, {'edge_type': 'AST_CHILD'}), (6, 11, {'edge_type': 'AST_CHILD'}), (6, 29, {'edge_type': 'ASSOCIATED_TOKEN'}), (6, 30, {'edge_type': 'ASSOCIATED_TOKEN'}), (6, 43, {'edge_type': 'ASSOCIATED_SYMBOL'}), (6, 26, {'edge_type': 'COMMENT'}), (6, 46, {'edge_type': 'AST_CHILD'}), (7, 8, {'edge_type': 'AST_CHILD'}), (8, 25, {'edge_type': 'ASSOCIATED_TOKEN'}), (9, 10, {'edge_type': 'AST_CHILD'}), (10, 27, {'edge_type': 'ASSOCIATED_TOKEN'}), (11, 12, {'edge_type': 'AST_CHILD'}), (12, 13, {'edge_type': 'AST_CHILD'}), (12, 31, {'edge_type': 'ASSOCIATED_TOKEN'}), (12, 37, {'edge_type': 'ASSOCIATED_TOKEN'}), (13, 14, {'edge_type': 'AST_CHILD'}), (14, 17, {'edge_type': 'AST_CHILD'}), (14, 19, {'edge_type': 'AST_CHILD'}), (14, 33, {'edge_type': 'ASSOCIATED_TOKEN'}), (14, 34, {'edge_type': 'ASSOCIATED_TOKEN'}), (14, 36, {'edge_type': 'ASSOCIATED_TOKEN'}), (17, 18, {'edge_type': 'AST_CHILD'}), (18, 32, {'edge_type': 'ASSOCIATED_TOKEN'}), (19, 20, {'edge_type': 'AST_CHILD'}), (20, 35, {'edge_type': 'ASSOCIATED_TOKEN'}), (21, 22, {'edge_type': 'NEXT_TOKEN'}), (22, 23, {'edge_type': 'NEXT_TOKEN'}), (23, 24, {'edge_type': 'NEXT_TOKEN'}), (24, 25, {'edge_type': 'NEXT_TOKEN'}), (25, 27, {'edge_type': 'NEXT_TOKEN'}), (27, 45, {'edge_type': 'NEXT_TOKEN'}), (29, 30, {'edge_type': 'NEXT_TOKEN'}), (29, 46, {'edge_type': 'NEXT_TOKEN'}), (30, 31, {'edge_type': 'NEXT_TOKEN'}), (31, 32, {'edge_type': 'NEXT_TOKEN'}), (32, 33, {'edge_type': 'NEXT_TOKEN'}), (33, 34, {'edge_type': 'NEXT_TOKEN'}), (33, 44, {'edge_type': 'ASSOCIATED_SYMBOL'}), (34, 35, {'edge_type': 'NEXT_TOKEN'}), (35, 36, {'edge_type': 'NEXT_TOKEN'}), (36, 37, {'edge_type': 'NEXT_TOKEN'}), (37, 38, {'edge_type': 'NEXT_TOKEN'}), (45, 28, {'edge_type': 'IN_TOKEN'}), (45, 46, {'edge_type': 'NEXT_TOKEN'}), (46, 28, {'edge_type': 'IN_TOKEN'})])

# %%
methods_source[0]
# Out:
# ['PUBLIC',
#  'STATIC',
#  'date',
#  'time',
#  'formatter',
#  'LPAREN',
#  'collection',
#  'LT',
#  'date',
#  'time',
#  'field',
#  'type',
#  'GT',
#  'fields',
#  'COMMA',
#  'boolean',
#  'extended',
#  'COMMA',
#  'boolean',
#  'strict',
#  'iso',
#  'RPAREN',
#  'LBRACE',
#  'IF',
#  'LPAREN',
#  'fields',
#  'EQEQ',
#  'null',
#  'BARBAR',
#  'fields',
#  'DOT',
#  'size',
#  'LPAREN',
#  'RPAREN',
#  'EQEQ',
#  '0',
#  'RPAREN',
#  'LBRACE',
#  'THROW',
#  'NEW',
#  'illegal',
#  'argument',
#  'exception',
#  'LPAREN',
#  'The fields must not be null or empty',
#  'RPAREN',
#  'SEMI',
#  'RBRACE',
#  'set',
#  'LT',
#  'date',
#  'time',
#  'field',
#  'type',
#  'GT',
#  'working',
#  'fields',
#  'EQ',
#  'NEW',
#  'hash',
#  'set',
#  'LT',
#  'GT',
#  'LPAREN',
#  'fields',
#  'RPAREN',
#  'SEMI',
#  'int',
#  'input',
#  'size',
#  'EQ',
#  'working',
#  'fields',
#  'DOT',
#  'size',
#  'LPAREN',
#  'RPAREN',
#  'SEMI',
#  'boolean',
#  'reduced',
#  'prec',
#  'EQ',
#  'false',
#  'SEMI',
#  'date',
#  'time',
#  'formatter',
#  'builder',
#  'bld',
#  'EQ',
#  'NEW',
#  'date',
#  'time',
#  'formatter',
#  'builder',
#  'LPAREN',
#  'RPAREN',
#  'SEMI',
#  'IF',
#  'LPAREN',
#  'working',
#  'fields',
#  'DOT',
#  'contains',
#  'LPAREN',
#  'date',
#  'time',
#  'field',
#  'type',
#  'DOT',
#  'month',
#  'of',
#  'year',
#  'LPAREN',
#  'RPAREN',
#  'RPAREN',
#  'RPAREN',
#  'LBRACE',
#  'reduced',
#  'prec',
#  'EQ',
#  'date',
#  'by',
#  'month',
#  'LPAREN',
#  'bld',
#  'COMMA',
#  'working',
#  'fields',
#  'COMMA',
#  'extended',
#  'COMMA',
#  'strict',
#  'iso',
#  'RPAREN',
#  'SEMI',
#  'RBRACE',
#  'ELSE',
#  'IF',
#  'LPAREN',
#  'working',
#  'fields',
#  'DOT',
#  'contains',
#  'LPAREN',
#  'date',
#  'time',
#  'field',
#  'type',
#  'DOT',
#  'day',
#  'of',
#  'year',
#  'LPAREN',
#  'RPAREN',
#  'RPAREN',
#  'RPAREN',
#  'LBRACE',
#  'reduced',
#  'prec',
#  'EQ',
#  'date',
#  'by',
#  'ordinal',
#  'LPAREN',
#  'bld',
#  'COMMA',
#  'working',
#  'fields',
#  'COMMA',
#  'extended',
#  'RPAREN',
#  'SEMI',
#  'RBRACE',
#  'ELSE',
#  'IF',
#  'LPAREN',
#  'working',
#  'fields',
#  'DOT',
#  'contains',
#  'LPAREN',
#  'date',
#  'time',
#  'field',
#  'type',
#  'DOT',
#  'week',
#  'of',
#  'weekyear',
#  'LPAREN',
#  'RPAREN',
#  'RPAREN',
#  'RPAREN',
#  'LBRACE',
#  'reduced',
#  'prec',
#  'EQ',
#  'date',
#  'by',
#  'week',
#  'LPAREN',
#  'bld',
#  'COMMA',
#  'working',
#  'fields',
#  'COMMA',
#  'extended',
#  'COMMA',
#  'strict',
#  'iso',
#  'RPAREN',
#  'SEMI',
#  'RBRACE',
#  'ELSE',
#  'IF',
#  'LPAREN',
#  'working',
#  'fields',
#  'DOT',
#  'contains',
#  'LPAREN',
#  'date',
#  'time',
#  'field',
#  'type',
#  'DOT',
#  'day',
#  'of',
#  'month',
#  'LPAREN',
#  'RPAREN',
#  'RPAREN',
#  'RPAREN',
#  'LBRACE',
#  'reduced',
#  'prec',
#  'EQ',
#  'date',
#  'by',
#  'month',
#  'LPAREN',
#  'bld',
#  'COMMA',
#  'working',
#  'fields',
#  'COMMA',
#  'extended',
#  'COMMA',
#  'strict',
#  'iso',
#  'RPAREN',
#  'SEMI',
#  'RBRACE',
#  'ELSE',
#  'IF',
#  'LPAREN',
#  'working',
#  'fields',
#  'DOT',
#  'contains',
#  'LPAREN',
#  'date',
#  'time',
#  'field',
#  'type',
#  'DOT',
#  'day',
#  'of',
#  'week',
#  'LPAREN',
#  'RPAREN',
#  'RPAREN',
#  'RPAREN',
#  'LBRACE',
#  'reduced',
#  'prec',
#  'EQ',
#  'date',
#  'by',
#  'week',
#  'LPAREN',
#  'bld',
#  'COMMA',
#  'working',
#  'fields',
#  'COMMA',
#  'extended',
#  'COMMA',
#  'strict',
#  'iso',
#  'RPAREN',
#  'SEMI',
#  'RBRACE',
#  'ELSE',
#  'IF',
#  'LPAREN',
#  'working',
#  'fields',
#  'DOT',
#  'remove',
#  'LPAREN',
#  'date',
#  'time',
#  'field',
#  'type',
#  'DOT',
#  'year',
#  'LPAREN',
#  'RPAREN',
#  'RPAREN',
#  'RPAREN',
#  'LBRACE',
#  'bld',
#  'DOT',
#  'append',
#  'LPAREN',
#  'constants',
#  'DOT',
#  'ye',
#  'RPAREN',
#  'SEMI',
#  'reduced',
#  'prec',
#  'EQ',
#  'true',
#  'SEMI',
#  'RBRACE',
#  'ELSE',
#  'IF',
#  'LPAREN',
#  'working',
#  'fields',
#  'DOT',
#  'remove',
#  'LPAREN',
#  'date',
#  'time',
#  'field',
#  'type',
#  'DOT',
#  'weekyear',
#  'LPAREN',
#  'RPAREN',
#  'RPAREN',
#  'RPAREN',
#  'LBRACE',
#  'bld',
#  'DOT',
#  'append',
#  'LPAREN',
#  'constants',
#  'DOT',
#  'we',
#  'RPAREN',
#  'SEMI',
#  'reduced',
#  'prec',
#  'EQ',
#  'true',
#  'SEMI',
#  'RBRACE',
#  'boolean',
#  'date',
#  'present',
#  'EQ',
#  'LPAREN',
#  'working',
#  'fields',
#  'DOT',
#  'size',
#  'LPAREN',
#  'RPAREN',
#  'LT',
#  'input',
#  'size',
#  'RPAREN',
#  'SEMI',
#  'time',
#  'LPAREN',
#  'bld',
#  'COMMA',
#  'working',
#  'fields',
#  'COMMA',
#  'extended',
#  'COMMA',
#  'strict',
#  'iso',
#  'COMMA',
#  'reduced',
#  'prec',
#  'COMMA',
#  'date',
#  'present',
#  'RPAREN',
#  'SEMI',
#  'IF',
#  'LPAREN',
#  'bld',
#  'DOT',
#  'can',
#  'build',
#  'formatter',
#  'LPAREN',
#  'RPAREN',
#  'EQEQ',
#  'false',
#  'RPAREN',
#  'LBRACE',
#  'THROW',
#  'NEW',
#  'illegal',
#  'argument',
#  'exception',
#  'LPAREN',
#  'No valid format for fields: ',
#  'PLUS',
#  'fields',
#  'RPAREN',
#  'SEMI',
#  'RBRACE',
#  'TRY',
#  'LBRACE',
#  'fields',
#  'DOT',
#  'retain',
#  'all',
#  'LPAREN',
#  'working',
#  'fields',
#  'RPAREN',
#  'SEMI',
#  'RBRACE',
#  'CATCH',
#  'LPAREN',
#  'unsupported',
#  'operation',
#  'exception',
#  'ex',
#  'RPAREN',
#  'LBRACE',
#  'RBRACE',
#  'RETURN',
#  'bld',
#  'DOT',
#  'to',
#  'formatter',
#  'LPAREN',
#  'RPAREN',
#  'SEMI',
#  'RBRACE']

# %%
methods_names[0]
# Out:
# ['for', 'fields']

# %%
for i in range(len(methods_source)):
    short_methods_source = []
    short_methods_names = []
    if len(methods_source[i]) < 100:
        short_methods_source.append(methods_source[i])
        short_methods_names.append(methods_names[i]) 
    pickle.dump({'methods_source': short_methods_source, 'methods_names': short_methods_names}, open('small_methods.pkl', 'wb'))

# %%
a = pickle.load(open('results/res3.pkl', 'rb'))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-65-b086d68ea3e0> in <module>
# ----> 1 a = pickle.load(open('results/res3.pkl', 'rb'))
#
# ~/miniconda3/envs/r252/lib/python3.7/site-packages/torch/storage.py in _load_from_bytes(b)
#     124
#     125 def _load_from_bytes(b):
# --> 126     return torch.load(io.BytesIO(b))
#     127
#     128
#
# ~/miniconda3/envs/r252/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module)
#     366         f = open(f, 'rb')
#     367     try:
# --> 368         return _load(f, map_location, pickle_module)
#     369     finally:
#     370         if new_fd:
#
# ~/miniconda3/envs/r252/lib/python3.7/site-packages/torch/serialization.py in _load(f, map_location, pickle_module)
#     540     unpickler = pickle_module.Unpickler(f)
#     541     unpickler.persistent_load = persistent_load
# --> 542     result = unpickler.load()
#     543
#     544     deserialized_storage_keys = pickle_module.load(f)
#
# ~/miniconda3/envs/r252/lib/python3.7/site-packages/torch/serialization.py in persistent_load(saved_id)
#     503             if root_key not in deserialized_objects:
#     504                 deserialized_objects[root_key] = restore_location(
# --> 505                     data_type(size), location)
#     506             storage = deserialized_objects[root_key]
#     507             if view_metadata is not None:
#
# ~/miniconda3/envs/r252/lib/python3.7/site-packages/torch/serialization.py in default_restore_location(storage, location)
#     112 def default_restore_location(storage, location):
#     113     for _, _, fn in _package_registry:
# --> 114         result = fn(storage, location)
#     115         if result is not None:
#     116             return result
#
# ~/miniconda3/envs/r252/lib/python3.7/site-packages/torch/serialization.py in _cuda_deserialize(obj, location)
#      93 def _cuda_deserialize(obj, location):
#      94     if location.startswith('cuda'):
# ---> 95         device = validate_cuda_device(location)
#      96         return obj.cuda(device)
#      97
#
# ~/miniconda3/envs/r252/lib/python3.7/site-packages/torch/serialization.py in validate_cuda_device(location)
#      77
#      78     if not torch.cuda.is_available():
# ---> 79         raise RuntimeError('Attempting to deserialize object on a CUDA '
#      80                            'device but torch.cuda.is_available() is False. '
#      81                            'If you are running on a CPU-only machine, '
#
# RuntimeError: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. If you are running on a CPU-only machine, please use torch.load with map_location='cpu' to map your storages to the CPU.

# %%
import pickle
a = pickle.load(open('results/res.pkl', 'rb'))
train_losses, val_losses, test_losses, test_f1_scores, test_rouge_2_scores, test_rouge_l_scores = a

# %%
test_rouge_l_scores
# Out:
# [0.3284275341548937,
#  0.3284275341548937,
#  0.32731287476276083,
#  0.3284275341548937,
#  0.3284275341548937,
#  0.33047489614962217,
#  0.31401685307240934,
#  0.3319126925643894,
#  0.3277267720605897,
#  0.33087264898799995,
#  0.33206521472846023,
#  0.3371196630996199,
#  0.33393976534591274,
#  0.338055353166293,
#  0.3409884349935031,
#  0.33294683048178003,
#  0.33854370260666494,
#  0.34351860007728935,
#  0.3463583311454447,
#  0.34685148439550406,
#  0.3475079066207305,
#  0.34656264786574864,
#  0.34953598414004394,
#  0.3459368009095942,
#  0.34957152130125985,
#  0.35219227388697955,
#  0.35242075506730164,
#  0.3582649300707974,
#  0.3520873954451674,
#  0.3452949252301963,
#  0.35407194982414375,
#  0.3529301305723352,
#  0.3525483118460436,
#  0.3552725539280774,
#  0.3597163424983266,
#  0.3575951096799577,
#  0.3582436853963817,
#  0.3609807344843824,
#  0.33060727461616873,
#  0.3564607068393826,
#  0.352615094947564,
#  0.3592835774937641,
#  0.3613241939467053,
#  0.3575060337561948,
#  0.3601423541162982,
#  0.3566695902683039,
#  0.3624000105424278,
#  0.36306157337179495,
#  0.36508514627454064,
#  0.36045723446213057,
#  0.35363878378555463,
#  0.3607076703182589,
#  0.363571833606343,
#  0.36642582289521686,
#  0.36521287302312705,
#  0.3669200456781056,
#  0.36878493015515623,
#  0.36534721193926273,
#  0.36645424851793656,
#  0.36638462411719425,
#  0.3633840875835089,
#  0.36440175702234157,
#  0.3670730965722375,
#  0.3608377090293955,
#  0.36197399931130875,
#  0.37031330983500693,
#  0.3671053875205048,
#  0.3676727543615227,
#  0.3683887708453146,
#  0.3701706049192595,
#  0.37132941137060826,
#  0.3674965177039313,
#  0.3640881782504134,
#  0.37637509019517823,
#  0.3743372074813193,
#  0.37161808169370464,
#  0.3753778215985875,
#  0.3718679066504192,
#  0.3752221661274247,
#  0.37436555423514073,
#  0.37435342025348856,
#  0.374440087576897,
#  0.3733828940864487,
#  0.37313579978926,
#  0.3740103187437272,
#  0.37739004717865016,
#  0.380207870176163,
#  0.3763875496490998,
#  0.3738820010396689,
#  0.38186432096203177,
#  0.3602990140878342,
#  0.37994748109662463,
#  0.38292692881020846,
#  0.3794805631673861,
#  0.3785616415725613,
#  0.3825296444879588]
